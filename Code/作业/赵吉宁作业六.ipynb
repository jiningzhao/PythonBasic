# %%
#作业：父类Clock，包括小时，分钟，秒
        #1）计算上面的时间之后指定m小时，n分钟，k秒之后的时间（计算结果要包括几天以后）
        #2）计算上面的时间之前指定m小时，n分钟，k秒之后的时间（计算结果要包括几天之前）
        #3）函数参数为时，分，秒，将传入的时分秒显示成“小时：分钟：秒AM”的格式，最后显示的AM、PM表示上下午
        #在主程序中创建对象，初始时间是15:26:35，计算此时间之后的53:42：40的时间，此时间之前53:42:40的时间，并打印结果
#子类myTime，包括年，月，日，小时，分钟
        #1）计算上面的时间之后指定m小时，n分钟，k秒之后的时间（xx年xx月xx日xx：xx：xx）
        #2）计算上面的时间之前指定m小时，n分钟，k秒之后的时间（xx年xx月xx日xx：xx：xx）
        #3）函数参数为年，月，日，时，分，秒，将传入的时分秒显示成“xx年xx月xx日小时：分钟：秒AM”的格式，最后显示的AM、PM代表上下午
        # 为了计算简便，假设所有月份都是30天
        #在主程序中创建对象，初始时间是15:26:35，计算此时间之后的53:42：40的时间，此时间之前53:42:40的时间，并打印结果
class Clock(object):
    __day=0
    __M='AM'
    def __init__(self,hour,minute,second):
        self.__hour=hour
        self.__min=minute
        self.__sec=second
    def display(d,h,m,s):
        str1='AM'
        if h>12:
            str1='PM'
            h-=12
        else:
            str1='AM'
        print('{:0>2d}天之后{:0>2d}:{:0>2d}:{:0>2d}'.format(d,h,m,s)+str1)
    def After(self,h,m,s):
        second=(self.__sec+s)%60
        second_zheng=(self.__sec+s)//60    #需要向分钟进位部分
        minute=(self.__min+m+second_zheng)%60
        minute_zheng=(self.__min+m+second_zheng)//60
        hour=(self.__hour+h+minute_zheng)%24
        hour_zheng=(self.__hour+h+minute_zheng)//24
        day=self.__day+hour_zheng
        Clock.display(day,hour,minute,second)   #显示时间
#     def Before(self,h,m,s):
#         second=(self.__sec-s)%60
#         second_zheng=(self.__sec-3)//60
#         minute=(self.__min-m+second_zheng)%60
#         minute_zheng=(self.__min-m+second_zheng)//60
#         hour=(self.__hour-h+minute_zheng)%24
#         Clock.display(hour,minute,second)
# class myTime(Clock):
#     def __init__(self,year,month,day,hour,minute,second):
#         super(myTime,self).__init__(hour,minute,second)
#         self.__year=year
#         self.__month=month
#         self.__day=day
#         self.__k=day
#     def afterTime(self,m,n,k):
#         self.__day=self.__k
#         super(myTime,self).afterTime(m,n,k)
#         d1=self.__day+self._Clock__day
#         self.__day=(d1+30)%30
#         self.__month+=d1//30
#         mon1=self.__month+12
#         self.__month=mon1%12
#         self.__year+=(mon1-12)//12
#         return self.__year,self.__month,self.__day,self.xianshi,self._Clock__minute,self._Clock__second,Clock._Clock__M
#     def beforeTime(self,m,n,k):
#         self.__day=self.__k
#         super(myTime,self).beforeTime(m,n,k)
#         d2=self.__day-self._Clock__day
#         self.__day=30-abs(d2-30)%30
#         self.__month-=abs(d2-30)//30
#         mon2=self.__month-12
#         self.__month=abs(mon2)%12
#         self.__year-=abs(mon2+12)//12
#         return self.__year,self.__month,self.__day,self.xianshi,self._Clock__minute,self._Clock__second,Clock._Clock__M
#     def show(self):
#         super(myTime,self).show()
#         print('{}年{}月{}日'.format(self.__year,self.__month,self.__day))
# mytime=myTime(2018,3,5,15,26,35)
# mytime.show()
# m2,n2,k2=53,42,40
# yy,mon,rr,hh,mm,ss,MM=mytime.afterTime(m2,n2,k2)
# print('{:0>2d}:{:0>2d}:{:0>2d}之后的时间为:{}年{}月{}日{:0>2d}:{:0>2d}:{:0>2d}.{}'.format(m2,n2,k2,yy,mon,rr,hh,mm,ss,MM))
# m5,n5,k5=53,42,40
# yy3,mon3,rr3,hh3,mm3,ss3,MM3=mytime.afterTime(m5,n5,k5)
# print('{:0>2d}:{:0>2d}:{:0>2d}之前的时间为:{}年{}月{}日{:0>2d}:{:0>2d}:{:0>2d}.{}'.format(m5,n5,k5,yy3,mon3,rr3,hh3,mm3,ss3,MM3))
c=Clock(15,26,35)
# c.show()
# m2,n2,k2=53,42,40
c.After(53,42,40)
print('{:0>2d}:{:0>2d}:{:0>2d}之后的时间为:{:0>2d}天后的{:0>2d}:{:0>2d}:{:0>2d}.{}'.format(m2,n2,k2,dd,hh,mm,ss,MM))
# m4,n4,k4=53,42,40
# dd1,hh1,mm1,ss1,MM1=c.beforeTime(m4,n4,k4)
# print('{:0>2d}:{:0>2d}:{:0>2d}之前的时间为:{:0>2d}天前的{:0>2d}:{:0>2d}:{:0>2d}.{}'.format(m4,n4,k4,dd1,hh1,mm1,ss1,MM1))
# Out:
# 02天之后09:09:15PM
# 53:42:40之后的时间为:02天后的09:09:15.PM
